# %% [markdown]
# # Create yearly images
# Generate yearly composite images from GFW and OBIS data.

# %%
# %pip install duckdb datashader colorcet
# Out:
# Requirement already satisfied: duckdb in /opt/conda/lib/python3.11/site-packages (1.5.1)
# Requirement already satisfied: datashader in /opt/conda/lib/python3.11/site-packages (0.19.0)
# Requirement already satisfied: colorcet in /opt/conda/lib/python3.11/site-packages (3.1.0)
# Requirement already satisfied: multipledispatch in /opt/conda/lib/python3.11/site-packages (from datashader) (1.0.0)
# Requirement already satisfied: numba in /opt/conda/lib/python3.11/site-packages (from datashader) (0.65.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (from datashader) (2.4.2)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from datashader) (26.0)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (from datashader) (3.0.1)
# Requirement already satisfied: param in /opt/conda/lib/python3.11/site-packages (from datashader) (2.3.3)
# Requirement already satisfied: pyct in /opt/conda/lib/python3.11/site-packages (from datashader) (0.6.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from datashader) (2.32.5)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.11/site-packages (from datashader) (1.17.1)
# Requirement already satisfied: toolz in /opt/conda/lib/python3.11/site-packages (from datashader) (1.1.0)
# Requirement already satisfied: xarray in /opt/conda/lib/python3.11/site-packages (from datashader) (2026.2.0)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in /opt/conda/lib/python3.11/site-packages (from numba->datashader) (0.47.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas->datashader) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datashader) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->datashader) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->datashader) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->datashader) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests->datashader) (2026.2.25)
# Note: you may need to restart the kernel to use updated packages.

# %%
import duckdb
import datashader as ds
import datashader.transfer_functions as tf
import colorcet as cc
from PIL import Image
import os

Image.MAX_IMAGE_PIXELS = None

# %%
YEARS = range(2012, 2025 + 1)
SPECIES = ["*"]
OUTPUT_DIR = "/mnt/shared_data/finflow/images/yearly"
W, H = 6000, 3000

# %%
cvs = ds.Canvas(plot_width=W, plot_height=H, x_range=(-180, 180), y_range=(-90, 90))

for year in YEARS:
    df_gfw = duckdb.query(f"SELECT lon, lat, hours FROM read_parquet('/mnt/shared_data/finflow/gfw_raw/{year}/*.parquet')").to_df()
    agg_gfw = cvs.points(df_gfw, 'lon', 'lat', ds.sum('hours'))
    img_gfw = tf.shade(agg_gfw, cmap=cc.fire, how='log').to_pil().convert("RGBA")

    for spec in SPECIES:
        query_obis = f"""SELECT decimalLongitude as lon, decimalLatitude as lat FROM read_parquet('/mnt/shared_data/finflow/obis_raw/{spec}/*/*.parquet') 
                         WHERE year(eventDate) = {year} AND lon IS NOT NULL AND lat IS NOT NULL"""
        df_obis = duckdb.query(query_obis).to_df()
        
        combined = Image.open("/mnt/shared_data/finflow/images/base_map.png").resize((W, H)).convert("RGBA")
        #combined = Image.new("RGBA", (W, H), (0, 0, 0, 255))
        combined.alpha_composite(img_gfw)
        
        if not df_obis.empty:
            agg_obis = cvs.points(df_obis, 'lon', 'lat', ds.count())
            img_obis = tf.shade(agg_obis, cmap=["#90ee90", "#00ff00"], how='log').to_pil().convert("RGBA")
            combined.alpha_composite(img_obis)
        
        file_spec = spec.replace("*", "all").replace(" ", "_")
        save_path = os.path.join(OUTPUT_DIR, f"{year}_{file_spec}.png")
        combined.save(save_path)
        print(f"Saved: {year} - {spec}")
# Out:
# Saved: 2012 - *
# Saved: 2013 - *
# Saved: 2014 - *
# Saved: 2015 - *
# Saved: 2016 - *
# Saved: 2017 - *
# Saved: 2018 - *
# Saved: 2019 - *
# Saved: 2020 - *
# Saved: 2021 - *
# Saved: 2022 - *
# Saved: 2023 - *
# Saved: 2024 - *
# Saved: 2025 - *

# %%
import shutil
import os

SOURCE_DIR = "/mnt/shared_data/finflow/images/yearly/"
OUTPUT_FILENAME = "/mnt/shared_data/finflow/images/yearly_zip"

# Check if directory exists before zipping
if os.path.exists(SOURCE_DIR):
    print(f"Starting compression of {SOURCE_DIR}...")
    
    # make_archive automatically adds the .zip extension
    output_path = shutil.make_archive(OUTPUT_FILENAME, 'zip', SOURCE_DIR)
    
    print(f"Success! Archive created at: {output_path}")
else:
    print(f"Error: The directory {SOURCE_DIR} does not exist.")
# Out:
# Starting compression of /mnt/shared_data/finflow/images/yearly/...
# Success! Archive created at: /mnt/shared_data/finflow/images/yearly_zip.zip
