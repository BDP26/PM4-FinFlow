# %%
# %pip install gfw-api-python-client
# %pip install folium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [folium]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Fourwings API

# %%
import gfwapiclient as gfw

API_KEY = "eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6ImtpZEtleSJ9.eyJkYXRhIjp7Im5hbWUiOiJmaW5mbG93IiwidXNlcklkIjo1NjU2NSwiYXBwbGljYXRpb25OYW1lIjoiZmluZmxvdyIsImlkIjo0NjE5LCJ0eXBlIjoidXNlci1hcHBsaWNhdGlvbiJ9LCJpYXQiOjE3NzIxMTIyODAsImV4cCI6MjA4NzQ3MjI4MCwiYXVkIjoiZ2Z3IiwiaXNzIjoiZ2Z3In0.VOLCGk5uxKq_FxeVsE9WiglWdhlDwk3bfypI7BbcjNdGcvDKxPERHFY2ZR_UTOH47I89j0Qn9oWTksCuNTUe60HUjPKbfPi3QDarS4r-D-mj6tlk17S9pueFoXwCGDtOL1ge-J60sMzh7CKSELYYsxBuXySNmEUMdLsdLclvHYDeF7d69h7TU73BDkoZ-fT48jWQ8hk9VQCulAC5zyrFrLcWgv0j1SXJ7QaEm37qHYCg6WUKU4jX0loiA3lBoA6NwvT_IUZNUltqTO8L991mfCvHoZ8Ky3QsSVUGcEflhBnDrqaLS2YkgTP_Os-hml7605GY32s3iyin2KY5oGzqGpIdPFBg6KKrKSrXEM-MkTehBihHubVR3hG63ly2U6wXOh2bPf50y0t8mZLI69i3iZgqOSP2ztAjW5dJOW4JnK-lgn6xw7825UzNERfNEVPTeTYgcBCYvZVie0e9f7Ajl1BqYx-frN1qJd9G1wqj_UesUNEq7y3rCBQw72FiUPtr"

gfw_client = gfw.Client(
    access_token=API_KEY,
)

cargo_presence = await gfw_client.fourwings.create_ais_presence_report(
    dataset="public-global-presence:latest",
    filters=["vessel_type = 'cargo'"],
    spatial_resolution="LOW",
    temporal_resolution="ENTIRE",
    start_date="2025-01-01",
    end_date="2025-02-01",
    region={
        "dataset": "public-eez-areas",
        "id": "5690",
    }
)

# %%
cargo_presence_df = cargo_presence.df()
cargo_presence_df.info()
cargo_presence_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14801 entries, 0 to 14800
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   date                     14801 non-null  object
#  1   detections               0 non-null      object
#  2   flag                     0 non-null      object
#  3   gear_type                0 non-null      object
#  4   hours                    14801 non-null  float64
#  5   vessel_ids               14801 non-null  int64
#  6   vessel_id                0 non-null      object
#  7   vessel_type              0 non-null      object
#  8   entry_timestamp          0 non-null      object
#  9   exit_timestamp           0 non-null      object
#  10  first_transmission_date  0 non-null      object
#  11  last_transmission_date   0 non-null      object
#  12  imo                      0 non-null      object
#  13  mmsi                     0 non-null      object
# ...

# %%
help(gfw_client.fourwings.create_ais_presence_report)
# Out:
# Help on method create_ais_presence_report in module gfwapiclient.resources.fourwings.resources:
#
# ...

# %% [markdown]
# # Bulk Load

# %%
import time
timestamp = int(time.time() * 1000)
dataset = "public-global-presence:latest"
region_dataset = "public-eez-areas"
region_id = "8466"  # Argentinian Exclusive Economic Zone
name = f"{dataset.split(':')[0]}_{region_dataset}__{region_id}_{timestamp}"

create_bulk_report_result = await gfw_client.bulk_downloads.create_bulk_report(
    name=name,
    dataset=dataset,
    region={
        "dataset": region_dataset,
        "id": region_id,
    },
    #filters=["label = 'oil'", "label_confidence = 'high'"],
)

create_bulk_report_df = create_bulk_report_result.df()

print(create_bulk_report_df.info())
print(create_bulk_report_df.head())
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# File /opt/conda/lib/python3.11/site-packages/gfwapiclient/resources/bulk_downloads/resources.py:477, in BulkDownloadResource._prepare_create_bulk_report_request_body(self, name, dataset, geojson, format, region, filters)
#     469     _request_body: Dict[str, Any] = {
#     470         "name": name,  # TODO: generate based on dataset name and timestamp (YYYMMDDHHmmss) / uuidv4
#     471         "dataset": _dataset,
#    (...)    475         "filters": filters or None,
#     476     }
# --> 477     request_body: BulkReportCreateBody = BulkReportCreateBody(**_request_body)
#     478 except pydantic.ValidationError as exc:
#
# File /opt/conda/lib/python3.11/site-packages/pydantic/main.py:250, in BaseModel.__init__(self, **data)
#     249 __tracebackhide__ = True
# ...

# %%
create_bulk_report_data = create_bulk_report_result.data()
print((
    create_bulk_report_data.id,
    create_bulk_report_data.name,
    create_bulk_report_data.status,
    create_bulk_report_data.created_at,
))

bulk_report_result = await gfw_client.bulk_downloads.get_bulk_report_by_id(
    id=create_bulk_report_data.id
)
# Out:
# ('7f4bcae4-5085-416d-bc8b-9039904010d0', 'public-fixed-infrastructure-data_public-eez-areas__8466_1772181153367', 'pending', datetime.datetime(2026, 2, 27, 8, 32, 35, 427000, tzinfo=TzInfo(0)))

# %% [markdown]
# # Map

# %%
import folium
from folium.plugins import HeatMap
import pandas as pd

df = cargo_presence_df

# 1. Prepare the data for Folium
# Folium's HeatMap expects a list of [lat, lon, weight]
heat_data = df[['lat', 'lon', 'hours']].values.tolist()

# 2. Create a base map
# Center the map based on the average coordinates of your data
map_center = [df['lat'].mean(), df['lon'].mean()]
m = folium.Map(location=map_center, zoom_start=5, tiles='cartodbdark_matter')

# 3. Add the HeatMap layer
# radius: size of the glow around each point
# blur: how smooth the transition is
HeatMap(heat_data).add_to(m)

# 4. Display the map in your notebook
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...
