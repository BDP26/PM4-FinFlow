# %%
import ray
import requests
import pandas as pd
import pyarrow.parquet as pq
import os
import glob
import time

# %% [markdown]
# ### ==========================================
# ### 1. LIVE-INVENTAR FUNKTION (Head-Node)
# ### ==========================================

# %%
def fetch_live_inventory(groups=["Cetacea", "Phocidae", "Cheloniidae"], start_year=2000):
    """Holt das aktuellste Inventar direkt von OBIS, bevor der Download startet."""
    print("Erstelle Live-Inventar von OBIS...")
    all_dfs = []
    
    for group in groups:
        url = "https://api.obis.org/v3/facet"
        params = {"facets": "scientificName", "scientificname": group, "startdate": f"{start_year}-01-01"}
        
        try:
            res = requests.get(url, params=params)
            if res.status_code == 200:
                results = res.json().get("results", {}).get("scientificName", [])
                if results:
                    df = pd.DataFrame(results).rename(columns={"key": "scientificName", "records": "count"})
                    df["category"] = group # Hier speichern wir die Überart
                    all_dfs.append(df)
                    print(f"  -> {group}: {len(df)} Spezies gefunden.")
        except Exception as e:
            print(f"  -> Fehler bei {group}: {e}")
            
    if all_dfs:
        return pd.concat(all_dfs, ignore_index=True)
    return pd.DataFrame()

# %% [markdown]
# ### ==========================================
# ### 2. HILFSFUNKTION (Auf dem Worker)
# ### ==========================================

# %%
def get_resume_state(folder_path):
    """
    Sucht die letzte ID und zählt alle bisher geladenen Zeilen.
    Nutzt pyarrow für extrem schnelles Auslesen der Metadaten (ohne RAM-Belastung).
    """
    files = glob.glob(f"{folder_path}/*.parquet")
    if not files:
        return None, 0
    
    total_rows = 0
    for f in files:
        try:
            # Schnelles Lesen der Metadaten, ohne die ganze Datei in den RAM zu laden
            total_rows += pq.read_metadata(f).num_rows
        except Exception:
            pass
            
    # Neueste Datei für die last_id finden
    latest_file = max(files, key=os.path.getctime)
    try:
        df_latest = pd.read_parquet(latest_file, columns=['id'])
        if not df_latest.empty:
            last_id = df_latest.iloc[-1]['id']
            return last_id, total_rows
    except Exception as e:
        print(f"Warnung beim Lesen von {latest_file}: {e}")
        
    return None, total_rows

# %% [markdown]
# ### ==========================================
# ### 3. DIE RAY WORKER-TASK
# ### ==========================================

# %%
@ray.remote(num_cpus=1)
def download_obis_species(category, scientific_name, expected_count, storage_dir, start_year=2000):
    
    # NEU: Verschachtelte Ordnerstruktur (Überart -> Art)
    species_dir = os.path.join(storage_dir, category, scientific_name.replace(" ", "_").lower())
    os.makedirs(species_dir, exist_ok=True)
    
    start_date = f"{start_year}-01-01"
    chunk_size = 10000
    
    # NEU: Korrekte Wiederaufnahme des Counters
    last_id, all_downloaded = get_resume_state(species_dir)
    
    # Wenn wir schon alles haben, direkt beenden
    if all_downloaded >= expected_count and last_id:
        return f"ÜBERSPRUNGEN: {scientific_name} (Bereits {all_downloaded} Punkte vorhanden)"
    
    status_msg = f"RESUME bei ID {last_id} ({all_downloaded} bereits da)" if last_id else "NEUER DOWNLOAD"
    print(f"[START] {scientific_name} | Ziel: {expected_count} | {status_msg}")

    while True:
        url = f"https://api.obis.org/v3/occurrence?scientificname={scientific_name}&startdate={start_date}&size={chunk_size}"
        if last_id:
            url += f"&after={last_id}"
            
        try:
            r = requests.get(url, timeout=60)
            if r.status_code != 200:
                time.sleep(5) 
                continue
                
            results = r.json().get('results', [])
            if not results:
                break # Keine Daten mehr verfügbar
                
            df_chunk = pd.DataFrame(results)
            if 'eventDate' in df_chunk.columns:
                df_chunk['eventDate'] = pd.to_datetime(df_chunk['eventDate'], errors='coerce', utc=True)
                
            # Speichern
            timestamp = int(time.time() * 1000)
            chunk_file = os.path.join(species_dir, f"chunk_{timestamp}.parquet")
            df_chunk.to_parquet(chunk_file, index=False)
            
            # Counter und ID aktualisieren
            last_id = results[-1].get('id')
            all_downloaded += len(results) # Jetzt stimmt die Zahl auch nach einem Neustart!
            
            print(f"[{scientific_name}] {all_downloaded} / {expected_count} geladen...")
            time.sleep(1)
            
        except Exception as e:
            print(f"[NETZWERK-FEHLER] {scientific_name}: {e}. Retry...")
            time.sleep(5)
            
    return f"ERFOLG: {scientific_name} ({all_downloaded} Datensätze gesichert im Ordner {category})"

# %% [markdown]
# ### ==========================================
# ### 4. DER ORCHESTRATOR (Hauptprogramm)
# ### ==========================================

# %%
# 1. Live-Inventar erstellen
inventory_df = fetch_live_inventory()
if inventory_df.empty:
    print("Konnte kein Inventar erstellen. Beende Programm.")
    exit(1)
    
# Optional: Inventar zur Sicherheit lokal als Backup speichern
inventory_df.to_csv("finflow_live_inventory.csv", index=False)

# Nur Arten mit mehr als 100 Einträgen berücksichtigen
active_tasks = inventory_df[inventory_df['count'] > 100]

# 2. Ray initialisieren
if not ray.is_initialized():
    ray.init(address='auto') # oder ray.init() für lokale Tests

CLUSTER_STORAGE_DIR = "/mnt/shared_data/finflow/obis_raw" 
print(f"\nStarte verteilten Download für {len(active_tasks)} Spezies in {CLUSTER_STORAGE_DIR}...")

# 3. Jobs verteilen
task_references = []
for index, row in active_tasks.iterrows():
    task_ref = download_obis_species.remote(
        category=row['category'],           # Überart (Cetacea, etc.)
        scientific_name=row['scientificName'], # Art (Megaptera novaeangliae, etc.)
        expected_count=row['count'],
        storage_dir=CLUSTER_STORAGE_DIR
    )
    task_references.append(task_ref)
    
# 4. Warten auf Abschluss
results = ray.get(task_references)

print("\nALLE DOWNLOADS ABGESCHLOSSEN!")
for res in results:
    print(res)
    
ray.shutdown()
# Out:
# 🔄 Erstelle Live-Inventar von OBIS...
#   -> Cetacea: 10 Spezies gefunden.
# 2026-03-12 10:39:39,921	INFO worker.py:1669 -- Using address ray://10.10.1.98:10001 set in the environment variable RAY_ADDRESS
# 2026-03-12 10:39:39,922	INFO client_builder.py:241 -- Passing the following kwargs to ray.init() on the server: log_to_driver
#   -> Phocidae: 10 Spezies gefunden.
#   -> Cheloniidae: 9 Spezies gefunden.
# SIGTERM handler is not set because current thread is not the main thread.
# 📊 Starte verteilten Download für 27 Spezies in /mnt/shared_data/finflow/obis_raw...
# (download_obis_species pid=46201, ip=10.10.1.34) 🚀 [START] Megaptera novaeangliae | Ziel: 398452 | NEUER DOWNLOAD
# (download_obis_species pid=46198, ip=10.10.1.34) 🚀 [START] Balaenoptera physalus | Ziel: 207832 | NEUER DOWNLOAD
# (download_obis_species pid=46199, ip=10.10.1.34) 🚀 [START] Tursiops truncatus | Ziel: 128053 | NEUER DOWNLOAD
# (download_obis_species pid=2092291) 🚀 [START] Delphinidae | Ziel: 29142 | NEUER DOWNLOAD
# (download_obis_species pid=46335, ip=10.10.4.23) 🚀 [START] Phocoena phocoena | Ziel: 279037 | NEUER DOWNLOAD
# (download_obis_species pid=46336, ip=10.10.4.23) 🚀 [START] Halichoerus grypus | Ziel: 234351 | NEUER DOWNLOAD
# (download_obis_species pid=46197, ip=10.10.1.34) 🚀 [START] Lobodon carcinophagus | Ziel: 107210 | NEUER DOWNLOAD
# (download_obis_species pid=2092298) 🚀 [START] Eschrichtius robustus | Ziel: 23729 | NEUER DOWNLOAD
# (download_obis_species pid=2092292) 🚀 [START] Physeter macrocephalus | Ziel: 51774 | NEUER DOWNLOAD
# (download_obis_species pid=2092299) 🚀 [START] Leptonychotes weddellii | Ziel: 341491 | NEUER DOWNLOAD
# (download_obis_species pid=2092297) 🚀 [START] Mirounga leonina | Ziel: 1004968 | NEUER DOWNLOAD
# (download_obis_species pid=2092296) 🚀 [START] Phoca largha | Ziel: 25056 | NEUER DOWNLOAD
# (download_obis_species pid=46345, ip=10.10.4.23) 🚀 [START] Mesoplodon densirostris | Ziel: 51909 | NEUER DOWNLOAD
# (download_obis_species pid=46337, ip=10.10.4.23) 🚀 [START] Pusa hispida | Ziel: 12353 | NEUER DOWNLOAD
# (download_obis_species pid=46342, ip=10.10.4.23) 🚀 [START] Histriophoca fasciata | Ziel: 10853 | NEUER DOWNLOAD
# (download_obis_species pid=46347, ip=10.10.4.23) 🚀 [START] Erignathus barbatus | Ziel: 10716 | NEUER DOWNLOAD
# (download_obis_species pid=46340, ip=10.10.4.23) 🚀 [START] Chelonia mydas | Ziel: 205674 | NEUER DOWNLOAD
# (download_obis_species pid=2092290) 🚀 [START] Balaenoptera acutorostrata | Ziel: 253568 | NEUER DOWNLOAD
# (download_obis_species pid=2092293) 🚀 [START] Delphinus delphis | Ziel: 93224 | NEUER DOWNLOAD
# (download_obis_species pid=46344, ip=10.10.4.23) 🚀 [START] Pusa hispida botnica | Ziel: 6575 | NEUER DOWNLOAD
# (download_obis_species pid=46334, ip=10.10.4.23) 🚀 [START] Phoca vitulina | Ziel: 87206 | NEUER DOWNLOAD
# (download_obis_species pid=47545, ip=10.10.3.63) 🚀 [START] Caretta caretta | Ziel: 153357 | NEUER DOWNLOAD
# (download_obis_species pid=47549, ip=10.10.3.63) 🚀 [START] Eretmochelys imbricata | Ziel: 11043 | NEUER DOWNLOAD
# (download_obis_species pid=47546, ip=10.10.3.63) 🚀 [START] Cheloniidae | Ziel: 11574 | NEUER DOWNLOAD
# (download_obis_species pid=47544, ip=10.10.3.63) 🚀 [START] Lepidochelys kempii | Ziel: 4510 | NEUER DOWNLOAD
# (download_obis_species pid=47541, ip=10.10.3.63) 🚀 [START] Lepidochelys olivacea | Ziel: 10926 | NEUER DOWNLOAD
# (download_obis_species pid=2092551) 🚀 [START] Natator depressus | Ziel: 2100 | NEUER DOWNLOAD
# (download_obis_species pid=46198, ip=10.10.1.34) 🛑 [NETZWERK-FEHLER] Balaenoptera physalus: HTTPSConnectionPool(host='api.obis.org', port=443): Read timed out. (read timeout=60). Retry...
# (download_obis_species pid=2092291) 🛑 [NETZWERK-FEHLER] Delphinidae: HTTPSConnectionPool(host='api.obis.org', port=443): Read timed out. (read timeout=60). Retry...
# (download_obis_species pid=2092296) 🛑 [NETZWERK-FEHLER] Phoca largha: HTTPSConnectionPool(host='api.obis.org', port=443): Read timed out. (read timeout=60). Retry...
# (download_obis_species pid=46342, ip=10.10.4.23) 🛑 [NETZWERK-FEHLER] Histriophoca fasciata: HTTPSConnectionPool(host='api.obis.org', port=443): Read timed out. (read timeout=60). Retry...
# (download_obis_species pid=46347, ip=10.10.4.23) 🛑 [NETZWERK-FEHLER] Erignathus barbatus: HTTPSConnectionPool(host='api.obis.org', port=443): Read timed out. (read timeout=60). Retry...
# (download_obis_species pid=2092290) 🛑 [NETZWERK-FEHLER] Balaenoptera acutorostrata: HTTPSConnectionPool(host='api.obis.org', port=443): Read timed out. (read timeout=60). Retry...
# (download_obis_species pid=2092293) 🛑 [NETZWERK-FEHLER] Delphinus delphis: HTTPSConnectionPool(host='api.obis.org', port=443): Read timed out. (read timeout=60). Retry...
# (download_obis_species pid=47545, ip=10.10.3.63) 🛑 [NETZWERK-FEHLER] Caretta caretta: HTTPSConnectionPool(host='api.obis.org', port=443): Read timed out. (read timeout=60). Retry...
# (download_obis_species pid=47549, ip=10.10.3.63) 🛑 [NETZWERK-FEHLER] Eretmochelys imbricata: HTTPSConnectionPool(host='api.obis.org', port=443): Read timed out. (read timeout=60). Retry...
# (download_obis_species pid=47546, ip=10.10.3.63) 🛑 [NETZWERK-FEHLER] Cheloniidae: HTTPSConnectionPool(host='api.obis.org', port=443): Read timed out. (read timeout=60). Retry...
# (download_obis_species pid=47541, ip=10.10.3.63) 🛑 [NETZWERK-FEHLER] Lepidochelys olivacea: HTTPSConnectionPool(host='api.obis.org', port=443): Read timed out. (read timeout=60). Retry...
# (download_obis_species pid=2092551) 📥 [Natator depressus] 2100 / 2100 geladen...
# (download_obis_species pid=46344, ip=10.10.4.23) 📥 [Pusa hispida botnica] 6575 / 6575 geladen...
# (download_obis_species pid=2092299) 📥 [Leptonychotes weddellii] 10000 / 341491 geladen...
# (download_obis_species pid=46197, ip=10.10.1.34) 📥 [Lobodon carcinophagus] 10000 / 107210 geladen...
# (download_obis_species pid=47544, ip=10.10.3.63) 📥 [Lepidochelys kempii] 4510 / 4510 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 10000 / 1004968 geladen...
# (download_obis_species pid=46337, ip=10.10.4.23) 📥 [Pusa hispida] 10000 / 12353 geladen...
# (download_obis_species pid=46345, ip=10.10.4.23) 📥 [Mesoplodon densirostris] 10000 / 51909 geladen...
# (download_obis_species pid=46340, ip=10.10.4.23) 📥 [Chelonia mydas] 10000 / 205674 geladen...
# (download_obis_species pid=46335, ip=10.10.4.23) 📥 [Phocoena phocoena] 10000 / 279037 geladen...
# (download_obis_species pid=46336, ip=10.10.4.23) 📥 [Halichoerus grypus] 10000 / 234351 geladen...
# (download_obis_species pid=46334, ip=10.10.4.23) 📥 [Phoca vitulina] 10000 / 87206 geladen...
# (download_obis_species pid=2092298) 📥 [Eschrichtius robustus] 10000 / 23729 geladen...
# (download_obis_species pid=2092292) 📥 [Physeter macrocephalus] 10000 / 51774 geladen...
# (download_obis_species pid=46199, ip=10.10.1.34) 📥 [Tursiops truncatus] 10000 / 128053 geladen...
# (download_obis_species pid=46201, ip=10.10.1.34) 📥 [Megaptera novaeangliae] 10000 / 398452 geladen...
# (download_obis_species pid=46198, ip=10.10.1.34) 🛑 [NETZWERK-FEHLER] Balaenoptera physalus: HTTPSConnectionPool(host='api.obis.org', port=443): Read timed out. (read timeout=60). Retry...
# (download_obis_species pid=2092291) 🛑 [NETZWERK-FEHLER] Delphinidae: HTTPSConnectionPool(host='api.obis.org', port=443): Read timed out. (read timeout=60). Retry...
# (download_obis_species pid=46347, ip=10.10.4.23) 🛑 [NETZWERK-FEHLER] Erignathus barbatus: HTTPSConnectionPool(host='api.obis.org', port=443): Read timed out. (read timeout=60). Retry...
# (download_obis_species pid=2092290) 🛑 [NETZWERK-FEHLER] Balaenoptera acutorostrata: HTTPSConnectionPool(host='api.obis.org', port=443): Read timed out. (read timeout=60). Retry...
# (download_obis_species pid=47545, ip=10.10.3.63) 🛑 [NETZWERK-FEHLER] Caretta caretta: HTTPSConnectionPool(host='api.obis.org', port=443): Read timed out. (read timeout=60). Retry...
# (download_obis_species pid=47546, ip=10.10.3.63) 🛑 [NETZWERK-FEHLER] Cheloniidae: HTTPSConnectionPool(host='api.obis.org', port=443): Read timed out. (read timeout=60). Retry...
# (download_obis_species pid=46197, ip=10.10.1.34) 📥 [Lobodon carcinophagus] 20000 / 107210 geladen...
# (download_obis_species pid=2092299) 📥 [Leptonychotes weddellii] 20000 / 341491 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 20000 / 1004968 geladen...
# (download_obis_species pid=46337, ip=10.10.4.23) 📥 [Pusa hispida] 18928 / 12353 geladen...
# (download_obis_species pid=46340, ip=10.10.4.23) 📥 [Chelonia mydas] 20000 / 205674 geladen...
# (download_obis_species pid=46335, ip=10.10.4.23) 📥 [Phocoena phocoena] 20000 / 279037 geladen...
# (download_obis_species pid=46345, ip=10.10.4.23) 📥 [Mesoplodon densirostris] 20000 / 51909 geladen...
# (download_obis_species pid=46336, ip=10.10.4.23) 📥 [Halichoerus grypus] 20000 / 234351 geladen...
# (download_obis_species pid=47549, ip=10.10.3.63) 📥 [Eretmochelys imbricata] 10000 / 11043 geladen...
# (download_obis_species pid=47541, ip=10.10.3.63) 📥 [Lepidochelys olivacea] 10000 / 10926 geladen...
# (download_obis_species pid=46334, ip=10.10.4.23) 📥 [Phoca vitulina] 20000 / 87206 geladen...
# (download_obis_species pid=2092293) 📥 [Delphinus delphis] 10000 / 93224 geladen...
# (download_obis_species pid=2092292) 📥 [Physeter macrocephalus] 20000 / 51774 geladen...
# (download_obis_species pid=46199, ip=10.10.1.34) 📥 [Tursiops truncatus] 20000 / 128053 geladen...
# (download_obis_species pid=46201, ip=10.10.1.34) 📥 [Megaptera novaeangliae] 20000 / 398452 geladen...
# (download_obis_species pid=2092298) 📥 [Eschrichtius robustus] 20000 / 23729 geladen...
# (download_obis_species pid=46342, ip=10.10.4.23) 📥 [Histriophoca fasciata] 10000 / 10853 geladen...
# (download_obis_species pid=2092296) 📥 [Phoca largha] 10000 / 25056 geladen...
# (download_obis_species pid=47541, ip=10.10.3.63) 📥 [Lepidochelys olivacea] 10926 / 10926 geladen...
# (download_obis_species pid=47549, ip=10.10.3.63) /tmp/ipykernel_4092/1699621600.py:38: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# (download_obis_species pid=47549, ip=10.10.3.63) 📥 [Eretmochelys imbricata] 11094 / 11043 geladen...
# (download_obis_species pid=46198, ip=10.10.1.34) 🛑 [NETZWERK-FEHLER] Balaenoptera physalus: HTTPSConnectionPool(host='api.obis.org', port=443): Read timed out. (read timeout=60). Retry...
# (download_obis_species pid=2092290) 🛑 [NETZWERK-FEHLER] Balaenoptera acutorostrata: HTTPSConnectionPool(host='api.obis.org', port=443): Read timed out. (read timeout=60). Retry...
# (download_obis_species pid=47545, ip=10.10.3.63) 🛑 [NETZWERK-FEHLER] Caretta caretta: HTTPSConnectionPool(host='api.obis.org', port=443): Read timed out. (read timeout=60). Retry...
# (download_obis_species pid=46342, ip=10.10.4.23) 📥 [Histriophoca fasciata] 10853 / 10853 geladen...
# (download_obis_species pid=2092298) 📥 [Eschrichtius robustus] 23729 / 23729 geladen...
# (download_obis_species pid=46197, ip=10.10.1.34) 📥 [Lobodon carcinophagus] 30000 / 107210 geladen...
# (download_obis_species pid=2092299) 📥 [Leptonychotes weddellii] 30000 / 341491 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 30000 / 1004968 geladen...
# (download_obis_species pid=46340, ip=10.10.4.23) 📥 [Chelonia mydas] 30000 / 205674 geladen...
# (download_obis_species pid=46335, ip=10.10.4.23) /tmp/ipykernel_4092/1699621600.py:38: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# (download_obis_species pid=46345, ip=10.10.4.23) 📥 [Mesoplodon densirostris] 30000 / 51909 geladen...
# (download_obis_species pid=46336, ip=10.10.4.23) 📥 [Halichoerus grypus] 30000 / 234351 geladen...
# (download_obis_species pid=46335, ip=10.10.4.23) 📥 [Phocoena phocoena] 30000 / 279037 geladen...
# (download_obis_species pid=46334, ip=10.10.4.23) 📥 [Phoca vitulina] 30000 / 87206 geladen...
# (download_obis_species pid=2092293) /tmp/ipykernel_4092/1699621600.py:38: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# (download_obis_species pid=47546, ip=10.10.3.63) 📥 [Cheloniidae] 10000 / 11574 geladen...
# (download_obis_species pid=46199, ip=10.10.1.34) 📥 [Tursiops truncatus] 30000 / 128053 geladen...
# (download_obis_species pid=2092291) 📥 [Delphinidae] 10000 / 29142 geladen...
# (download_obis_species pid=2092293) 📥 [Delphinus delphis] 20000 / 93224 geladen...
# (download_obis_species pid=2092292) 📥 [Physeter macrocephalus] 30000 / 51774 geladen...
# (download_obis_species pid=46201, ip=10.10.1.34) 📥 [Megaptera novaeangliae] 30000 / 398452 geladen...
# (download_obis_species pid=46347, ip=10.10.4.23) 📥 [Erignathus barbatus] 10000 / 10716 geladen...
# (download_obis_species pid=2092296) 📥 [Phoca largha] 20000 / 25056 geladen...
# (download_obis_species pid=46347, ip=10.10.4.23) 📥 [Erignathus barbatus] 10716 / 10716 geladen...
# (download_obis_species pid=46197, ip=10.10.1.34) 📥 [Lobodon carcinophagus] 40000 / 107210 geladen...
# (download_obis_species pid=2092299) 📥 [Leptonychotes weddellii] 40000 / 341491 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 40000 / 1004968 geladen...
# (download_obis_species pid=46340, ip=10.10.4.23) 📥 [Chelonia mydas] 40000 / 205674 geladen...
# (download_obis_species pid=46335, ip=10.10.4.23) /tmp/ipykernel_4092/1699621600.py:38: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# (download_obis_species pid=46345, ip=10.10.4.23) 📥 [Mesoplodon densirostris] 40000 / 51909 geladen...
# (download_obis_species pid=46336, ip=10.10.4.23) 📥 [Halichoerus grypus] 40000 / 234351 geladen...
# (download_obis_species pid=46335, ip=10.10.4.23) 📥 [Phocoena phocoena] 40000 / 279037 geladen...
# (download_obis_species pid=2092290) 📥 [Balaenoptera acutorostrata] 10000 / 253568 geladen...
# (download_obis_species pid=46334, ip=10.10.4.23) 📥 [Phoca vitulina] 40000 / 87206 geladen...
# (download_obis_species pid=2092292) 📥 [Physeter macrocephalus] 40000 / 51774 geladen...
# (download_obis_species pid=2092296) 📥 [Phoca largha] 25056 / 25056 geladen...
# (download_obis_species pid=46201, ip=10.10.1.34) 📥 [Megaptera novaeangliae] 40000 / 398452 geladen...
# (download_obis_species pid=46198, ip=10.10.1.34) 📥 [Balaenoptera physalus] 10000 / 207832 geladen...
# (download_obis_species pid=46199, ip=10.10.1.34) 📥 [Tursiops truncatus] 40000 / 128053 geladen...
# (download_obis_species pid=47546, ip=10.10.3.63) 📥 [Cheloniidae] 20000 / 11574 geladen...
# (download_obis_species pid=2092293) 📥 [Delphinus delphis] 30000 / 93224 geladen...
# (download_obis_species pid=47545, ip=10.10.3.63) 📥 [Caretta caretta] 10000 / 153357 geladen...
# (download_obis_species pid=2092291) 📥 [Delphinidae] 20000 / 29142 geladen...
# (download_obis_species pid=46197, ip=10.10.1.34) 📥 [Lobodon carcinophagus] 50000 / 107210 geladen...
# (download_obis_species pid=2092299) 📥 [Leptonychotes weddellii] 50000 / 341491 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 50000 / 1004968 geladen...
# (download_obis_species pid=46345, ip=10.10.4.23) 📥 [Mesoplodon densirostris] 50000 / 51909 geladen...
# (download_obis_species pid=46340, ip=10.10.4.23) 📥 [Chelonia mydas] 50000 / 205674 geladen...
# (download_obis_species pid=46335, ip=10.10.4.23) /tmp/ipykernel_4092/1699621600.py:38: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# (download_obis_species pid=46336, ip=10.10.4.23) 📥 [Halichoerus grypus] 50000 / 234351 geladen...
# (download_obis_species pid=2092292) /tmp/ipykernel_4092/1699621600.py:38: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# (download_obis_species pid=46335, ip=10.10.4.23) 📥 [Phocoena phocoena] 50000 / 279037 geladen...
# (download_obis_species pid=46334, ip=10.10.4.23) 📥 [Phoca vitulina] 50000 / 87206 geladen...
# (download_obis_species pid=2092290) 📥 [Balaenoptera acutorostrata] 20000 / 253568 geladen...
# (download_obis_species pid=2092293) 📥 [Delphinus delphis] 40000 / 93224 geladen...
# (download_obis_species pid=46201, ip=10.10.1.34) 📥 [Megaptera novaeangliae] 50000 / 398452 geladen...
# (download_obis_species pid=46198, ip=10.10.1.34) 📥 [Balaenoptera physalus] 20000 / 207832 geladen...
# (download_obis_species pid=46199, ip=10.10.1.34) 📥 [Tursiops truncatus] 50000 / 128053 geladen...
# (download_obis_species pid=2092292) 📥 [Physeter macrocephalus] 50000 / 51774 geladen...
# (download_obis_species pid=47546, ip=10.10.3.63) 📥 [Cheloniidae] 30000 / 11574 geladen...
# (download_obis_species pid=47545, ip=10.10.3.63) 📥 [Caretta caretta] 20000 / 153357 geladen...
# (download_obis_species pid=2092291) 📥 [Delphinidae]
 / 1004968 geladen...
# (download_obis_species pid=47546, ip=10.10.3.63) 📥 [Cheloniidae] 390000 / 11574 geladen...
# (download_obis_species pid=2092291) 📥 [Delphinidae] 390000 / 29142 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 440000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 450000 / 1004968 geladen...
# (download_obis_species pid=47546, ip=10.10.3.63) 📥 [Cheloniidae] 399258 / 11574 geladen...
# (download_obis_species pid=2092291) 📥 [Delphinidae] 400000 / 29142 geladen...
# (download_obis_species pid=2092291) 📥 [Delphinidae] 400261 / 29142 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 460000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 470000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 480000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 490000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 500000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 510000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 520000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 530000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 540000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 550000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 560000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 570000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 580000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 590000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 600000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 610000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 620000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 630000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 640000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 650000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 660000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 670000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 680000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 690000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 700000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 710000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 720000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 730000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 740000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 750000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 760000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 770000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 780000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 790000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 800000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 810000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 820000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 830000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 840000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 850000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 860000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 870000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 880000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 890000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 900000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 910000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 920000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 930000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 940000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 950000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 960000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 970000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 980000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 990000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 1000000 / 1004968 geladen...
# (download_obis_species pid=2092297) 📥 [Mirounga leonina] 1004968 / 1004968 geladen...
#
# 🎉 ALLE DOWNLOADS ABGESCHLOSSEN!
# ERFOLG: Megaptera novaeangliae (398452 Datensätze gesichert im Ordner Cetacea)
# ERFOLG: Phocoena phocoena (283896 Datensätze gesichert im Ordner Cetacea)
# ERFOLG: Balaenoptera acutorostrata (253568 Datensätze gesichert im Ordner Cetacea)
# ERFOLG: Balaenoptera physalus (207832 Datensätze gesichert im Ordner Cetacea)
# ERFOLG: Tursiops truncatus (129341 Datensätze gesichert im Ordner Cetacea)
# ERFOLG: Delphinus delphis (94699 Datensätze gesichert im Ordner Cetacea)
# ERFOLG: Mesoplodon densirostris (51909 Datensätze gesichert im Ordner Cetacea)
# ERFOLG: Physeter macrocephalus (51774 Datensätze gesichert im Ordner Cetacea)
# ERFOLG: Delphinidae (400261 Datensätze gesichert im Ordner Cetacea)
# ERFOLG: Eschrichtius robustus (23729 Datensätze gesichert im Ordner Cetacea)
# ERFOLG: Mirounga leonina (1004968 Datensätze gesichert im Ordner Phocidae)
# ERFOLG: Leptonychotes weddellii (341491 Datensätze gesichert im Ordner Phocidae)
# ERFOLG: Halichoerus grypus (234351 Datensätze gesichert im Ordner Phocidae)
# ERFOLG: Lobodon carcinophagus (107210 Datensätze gesichert im Ordner Phocidae)
# ERFOLG: Phoca vitulina (87293 Datensätze gesichert im Ordner Phocidae)
# ERFOLG: Phoca largha (25056 Datensätze gesichert im Ordner Phocidae)
# ERFOLG: Pusa hispida (18928 Datensätze gesichert im Ordner Phocidae)
# ERFOLG: Histriophoca fasciata (10853 Datensätze gesichert im Ordner Phocidae)
# ERFOLG: Erignathus barbatus (10716 Datensätze gesichert im Ordner Phocidae)
# ERFOLG: Pusa hispida botnica (6575 Datensätze gesichert im Ordner Phocidae)
# ERFOLG: Chelonia mydas (205674 Datensätze gesichert im Ordner Cheloniidae)
# ERFOLG: Caretta caretta (153357 Datensätze gesichert im Ordner Cheloniidae)
# ERFOLG: Cheloniidae (399258 Datensätze gesichert im Ordner Cheloniidae)
# ERFOLG: Eretmochelys imbricata (11094 Datensätze gesichert im Ordner Cheloniidae)
# ERFOLG: Lepidochelys olivacea (10926 Datensätze gesichert im Ordner Cheloniidae)
# ERFOLG: Lepidochelys kempii (4510 Datensätze gesichert im Ordner Cheloniidae)
# ERFOLG: Natator depressus (2100 Datensätze gesichert im Ordner Cheloniidae)

# %%
if ray.is_initialized():
    ray.shutdown()
# Out:
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::download_obis_species() (pid=2912, ip=10.10.1.98)
#   File "/tmp/ipykernel_4092/34365920.py", line 6, in download_obis_species
#   File "<frozen os>", line 215, in makedirs
#   File "<frozen os>", line 225, in makedirs
# PermissionError: [Errno 13] Permission denied: '/mnt/shared_data/finflow/obis_raw/Cetacea'
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::download_obis_species() (pid=2913, ip=10.10.1.98)
#   File "/tmp/ipykernel_4092/34365920.py", line 6, in download_obis_species
#   File "<frozen os>", line 215, in makedirs
#   File "<frozen os>", line 225, in makedirs
# PermissionError: [Errno 13] Permission denied: '/mnt/shared_data/finflow/obis_raw/Cetacea'
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::download_obis_species() (pid=2915, ip=10.10.1.98)
#   File "/tmp/ipykernel_4092/34365920.py", line 6, in download_obis_species
#   File "<frozen os>", line 215, in makedirs
#   File "<frozen os>", line 225, in makedirs
# PermissionError: [Errno 13] Permission denied: '/mnt/shared_data/finflow/obis_raw/Cetacea'
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::download_obis_species() (pid=2917, ip=10.10.1.98)
#   File "/tmp/ipykernel_4092/34365920.py", line 6, in download_obis_species
#   File "<frozen os>", line 215, in makedirs
#   File "<frozen os>", line 225, in makedirs
# PermissionError: [Errno 13] Permission denied: '/mnt/shared_data/finflow/obis_raw/Cetacea'
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::download_obis_species() (pid=2918, ip=10.10.1.98)
#   File "/tmp/ipykernel_4092/34365920.py", line 6, in download_obis_species
#   File "<frozen os>", line 215, in makedirs
#   File "<frozen os>", line 225, in makedirs
# PermissionError: [Errno 13] Permission denied: '/mnt/shared_data/finflow/obis_raw/Cetacea'
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::download_obis_species() (pid=2916, ip=10.10.1.98)
#   File "/tmp/ipykernel_4092/34365920.py", line 6, in download_obis_species
#   File "<frozen os>", line 215, in makedirs
#   File "<frozen os>", line 225, in makedirs
# PermissionError: [Errno 13] Permission denied: '/mnt/shared_data/finflow/obis_raw/Cetacea'
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::download_obis_species() (pid=2921, ip=10.10.1.98)
#   File "/tmp/ipykernel_4092/34365920.py", line 6, in download_obis_species
#   File "<frozen os>", line 215, in makedirs
#   File "<frozen os>", line 225, in makedirs
# PermissionError: [Errno 13] Permission denied: '/mnt/shared_data/finflow/obis_raw/Cetacea'
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::download_obis_species() (pid=2919, ip=10.10.1.98)
#   File "/tmp/ipykernel_4092/34365920.py", line 6, in download_obis_species
#   File "<frozen os>", line 215, in makedirs
#   File "<frozen os>", line 225, in makedirs
# PermissionError: [Errno 13] Permission denied: '/mnt/shared_data/finflow/obis_raw/Cetacea'
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::download_obis_species() (pid=2922, ip=10.10.1.98)
#   File "/tmp/ipykernel_4092/34365920.py", line 6, in download_obis_species
#   File "<frozen os>", line 215, in makedirs
#   File "<frozen os>", line 225, in makedirs
# PermissionError: [Errno 13] Permission denied: '/mnt/shared_data/finflow/obis_raw/Cetacea'
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::download_obis_species() (pid=2920, ip=10.10.1.98)
#   File "/tmp/ipykernel_4092/34365920.py", line 6, in download_obis_species
#   File "<frozen os>", line 215, in makedirs
#   File "<frozen os>", line 225, in makedirs
# PermissionError: [Errno 13] Permission denied: '/mnt/shared_data/finflow/obis_raw/Phocidae'
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::download_obis_species() (pid=43211, ip=10.10.4.23)
#   File "/tmp/ipykernel_4092/34365920.py", line 6, in download_obis_species
#   File "<frozen os>", line 215, in makedirs
#   File "<frozen os>", line 225, in makedirs
# PermissionError: [Errno 13] Permission denied: '/mnt/shared_data/finflow/obis_raw/Phocidae'
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::download_obis_species() (pid=2911, ip=10.10.1.98)
#   File "/tmp/ipykernel_4092/34365920.py", line 6, in download_obis_species
#   File "<frozen os>", line 215, in makedirs
#   File "<frozen os>", line 225, in makedirs
# PermissionError: [Errno 13] Permission denied: '/mnt/shared_data/finflow/obis_raw/Phocidae'
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::download_obis_species() (pid=43216, ip=10.10.4.23)
#   File "/tmp/ipykernel_4092/34365920.py", line 6, in download_obis_species
#   File "<frozen os>", line 215, in makedirs
#   File "<frozen os>", line 225, in makedirs
# PermissionError: [Errno 13] Permission denied: '/mnt/shared_data/finflow/obis_raw/Phocidae'
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::download_obis_species() (pid=43075, ip=10.10.1.34)
#   File "/tmp/ipykernel_4092/34365920.py", line 6, in download_obis_species
#   File "<frozen os>", line 215, in makedirs
#   File "<frozen os>", line 225, in makedirs
# PermissionError: [Errno 13] Permission denied: '/mnt/shared_data/finflow/obis_raw/Phocidae'
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::download_obis_species() (pid=43074, ip=10.10.1.34)
#   File "/tmp/ipykernel_4092/34365920.py", line 6, in download_obis_species
#   File "<frozen os>", line 215, in makedirs
#   File "<frozen os>", line 225, in makedirs
# PermissionError: [Errno 13] Permission denied: '/mnt/shared_data/finflow/obis_raw/Phocidae'
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::download_obis_species() (pid=2925, ip=10.10.1.98)
#   File "/tmp/ipykernel_4092/34365920.py", line 6, in download_obis_species
#   File "<frozen os>", line 215, in makedirs
#   File "<frozen os>", line 225, in makedirs
# PermissionError: [Errno 13] Permission denied: '/mnt/shared_data/finflow/obis_raw/Phocidae'
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::download_obis_species() (pid=2911, ip=10.10.1.98)
#   File "/tmp/ipykernel_4092/34365920.py", line 6, in download_obis_species
#   File "<frozen os>", line 215, in makedirs
#   File "<frozen os>", line 225, in makedirs
# PermissionError: [Errno 13] Permission denied: '/mnt/shared_data/finflow/obis_raw/Phocidae'
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::download_obis_species() (pid=2923, ip=10.10.1.98)
#   File "/tmp/ipykernel_4092/34365920.py", line 6, in download_obis_species
#   File "<frozen os>", line 215, in makedirs
#   File "<frozen os>", line 225, in makedirs
# PermissionError: [Errno 13] Permission denied: '/mnt/shared_data/finflow/obis_raw/Phocidae'
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::download_obis_species() (pid=2926, ip=10.10.1.98)
#   File "/tmp/ipykernel_4092/34365920.py", line 6, in download_obis_species
#   File "<frozen os>", line 215, in makedirs
#   File "<frozen os>", line 225, in makedirs
# PermissionError: [Errno 13] Permission denied: '/mnt/shared_data/finflow/obis_raw/Phocidae'
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::download_obis_species() (pid=43080, ip=10.10.1.34)
#   File "/tmp/ipykernel_4092/34365920.py", line 6, in download_obis_species
#   File "<frozen os>", line 215, in makedirs
#   File "<frozen os>", line 225, in makedirs
# PermissionError: [Errno 13] Permission denied: '/mnt/shared_data/finflow/obis_raw/Cheloniidae'
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::download_obis_species() (pid=2911, ip=10.10.1.98)
#   File "/tmp/ipykernel_4092/34365920.py", line 6, in download_obis_species
#   File "<frozen os>", line 215, in makedirs
#   File "<frozen os>", line 225, in makedirs
# PermissionError: [Errno 13] Permission denied: '/mnt/shared_data/finflow/obis_raw/Cheloniidae'
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::download_obis_species() (pid=43084, ip=10.10.1.34)
#   File "/tmp/ipykernel_4092/34365920.py", line 6, in download_obis_species
#   File "<frozen os>", line 215, in makedirs
#   File "<frozen os>", line 225, in makedirs
# PermissionError: [Errno 13] Permission denied: '/mnt/shared_data/finflow/obis_raw/Cheloniidae'
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::download_obis_species() (pid=2911, ip=10.10.1.98)
#   File "/tmp/ipykernel_4092/34365920.py", line 6, in download_obis_species
#   File "<frozen os>", line 215, in makedirs
#   File "<frozen os>", line 225, in makedirs
# PermissionError: [Errno 13] Permission denied: '/mnt/shared_data/finflow/obis_raw/Cheloniidae'
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::download_obis_species() (pid=2911, ip=10.10.1.98)
#   File "/tmp/ipykernel_4092/34365920.py", line 6, in download_obis_species
#   File "<frozen os>", line 215, in makedirs
#   File "<frozen os>", line 225, in makedirs
# PermissionError: [Errno 13] Permission denied: '/mnt/shared_data/finflow/obis_raw/Cheloniidae'
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::download_obis_species() (pid=43077, ip=10.10.1.34)
#   File "/tmp/ipykernel_4092/34365920.py", line 6, in download_obis_species
#   File "<frozen os>", line 215, in makedirs
#   File "<frozen os>", line 225, in makedirs
# PermissionError: [Errno 13] Permission denied: '/mnt/shared_data/finflow/obis_raw/Cheloniidae'
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::download_obis_species() (pid=2911, ip=10.10.1.98)
#   File "/tmp/ipykernel_4092/34365920.py", line 6, in download_obis_species
#   File "<frozen os>", line 215, in makedirs
#   File "<frozen os>", line 225, in makedirs
# PermissionError: [Errno 13] Permission denied: '/mnt/shared_data/finflow/obis_raw/Cheloniidae'
