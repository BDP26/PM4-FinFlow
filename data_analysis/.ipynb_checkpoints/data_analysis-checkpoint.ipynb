# %%
# %pip install duckdb
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### One Region

# %%
import duckdb

# Point exactly to the file shown in your sidebar
base_path = "/mnt/shared_data/finflow/gfw_raw/2025/SEAFDEC.parquet"

# Now the query will work
count = duckdb.query(f"SELECT count(*) FROM '{base_path}'").fetchone()[0]
print(f"Total points captured for SEAFDEC 2025: {count:,}")

# Look at the data
duckdb.query(f"SELECT * FROM '{base_path}' LIMIT 5").show()
# Out:
# Total points captured for SEAFDEC 2025: 4,556,076
# ┌────────┬────────┬────────┐
# │  lat   │  lon   │ hours  │
# │ double │ double │ double │
# ├────────┼────────┼────────┤
# │ -28.36 │ 109.72 │    1.0 │
# │ -28.35 │ 109.52 │    1.0 │
# │ -28.34 │ 109.64 │    2.0 │
# │ -28.34 │ 109.68 │    1.0 │
# │ -28.34 │  109.7 │    1.0 │
# └────────┴────────┴────────┘

# %%
import duckdb

base_path = "/mnt/shared_data/finflow/gfw_raw/2025/SEAFDEC.parquet"

# This returns a table of column names, types, and nullability
duckdb.query(f"DESCRIBE SELECT * FROM '{base_path}'").show()
# Out:
# ┌─────────────┬─────────────┬─────────┬─────────┬─────────┬─────────┐
# │ column_name │ column_type │  null   │   key   │ default │  extra  │
# │   varchar   │   varchar   │ varchar │ varchar │ varchar │ varchar │
# ├─────────────┼─────────────┼─────────┼─────────┼─────────┼─────────┤
# │ lat         │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ lon         │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ hours       │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# └─────────────┴─────────────┴─────────┴─────────┴─────────┴─────────┘

# %%
duckdb.query(f"""
    SELECT 
        round(lat, 1) as lat_bin, 
        round(lon, 1) as lon_bin, 
        sum(hours) as activity
    FROM '{base_path}'
    GROUP BY 1, 2
    ORDER BY activity DESC
    LIMIT 10
""").show()
# Out:
# ┌─────────┬─────────┬──────────┐
# │ lat_bin │ lon_bin │ activity │
# │ double  │ double  │  double  │
# ├─────────┼─────────┼──────────┤
# │    -7.2 │   112.7 │ 394616.0 │
# │    -6.1 │   106.9 │ 340870.0 │
# │    19.3 │   105.8 │ 256376.0 │
# │     1.3 │   103.9 │ 225593.0 │
# │     1.3 │   104.0 │ 216958.0 │
# │    13.1 │   100.9 │ 214950.0 │
# │     2.8 │   101.3 │ 191308.0 │
# │    10.7 │   106.8 │ 172578.0 │
# │    14.6 │   121.0 │ 164800.0 │
# │    13.8 │   109.3 │ 164370.0 │
# └─────────┴─────────┴──────────┘
#   10 rows            3 columns

# %%
duckdb.query(f"""
    SELECT 
        round(lat, 1) as lat_bin, 
        round(lon, 1) as lon_bin, 
        sum(hours) as total_hours,
        count(*) as data_points -- Number of distinct vessel-time entries
    FROM '{base_path}'
    GROUP BY 1, 2
    ORDER BY total_hours DESC
    LIMIT 10
""").show()
# Out:
# ┌─────────┬─────────┬─────────────┬─────────────┐
# │ lat_bin │ lon_bin │ total_hours │ data_points │
# │ double  │ double  │   double    │    int64    │
# ├─────────┼─────────┼─────────────┼─────────────┤
# │    -7.2 │   112.7 │    394616.0 │          38 │
# │    -6.1 │   106.9 │    340870.0 │          50 │
# │    19.3 │   105.8 │    256376.0 │          39 │
# │     1.3 │   103.9 │    225593.0 │          44 │
# │     1.3 │   104.0 │    216958.0 │          66 │
# │    13.1 │   100.9 │    214950.0 │          51 │
# │     2.8 │   101.3 │    191308.0 │          89 │
# │    10.7 │   106.8 │    172578.0 │          39 │
# │    14.6 │   121.0 │    164800.0 │          29 │
# │    13.8 │   109.3 │    164370.0 │          56 │
# └─────────┴─────────┴─────────────┴─────────────┘
#   10 rows                             4 columns

# %%
duckdb.query(f"""
    SELECT 
        round(lat * 2) / 2 as lat_zone, 
        round(lon * 2) / 2 as lon_zone,
        sum(hours) as total_effort,
        count(*) as unique_vessel_entries,
        sum(hours) / count(*) as intensity_ratio
    FROM '{base_path}'
    GROUP BY 1, 2
    ORDER BY intensity_ratio DESC
    LIMIT 10
""").show()
# Out:
# ┌──────────┬──────────┬──────────────┬───────────────────────┬────────────────────┐
# │ lat_zone │ lon_zone │ total_effort │ unique_vessel_entries │  intensity_ratio   │
# │  double  │  double  │    double    │         int64         │       double       │
# ├──────────┼──────────┼──────────────┼───────────────────────┼────────────────────┤
# │     37.0 │    138.0 │       9528.0 │                     1 │             9528.0 │
# │     42.5 │    141.5 │     114031.0 │                    19 │  6001.631578947368 │
# │     34.5 │    133.5 │     300732.0 │                    54 │  5569.111111111111 │
# │     36.0 │    140.5 │     122546.0 │                    28 │  4376.642857142857 │
# │     31.5 │    130.5 │      94298.0 │                    25 │            3771.92 │
# │     38.5 │    141.0 │      40725.0 │                    11 │ 3702.2727272727275 │
# │     38.5 │    141.5 │      38968.0 │                    11 │ 3542.5454545454545 │
# ...

# %% [markdown]
# ### Currently Downloaded

# %%
import duckdb

global_path = "/mnt/shared_data/finflow/gfw_raw/2024/*.parquet"

# This query aggregates data and shows you the source filename
stats = duckdb.query(f"""
    SELECT 
        filename, 
        count(*) as total_points,
        round(avg(hours), 2) as avg_activity,
        max(hours) as max_activity
    FROM read_parquet('{global_path}', filename=True)
    GROUP BY filename
""").df()

print(stats)
# Out:
#                                              filename  total_points  \
# 0   /mnt/shared_data/finflow/gfw_raw/2024/OSPESCA....        389540
# 1   /mnt/shared_data/finflow/gfw_raw/2024/GFCM.par...       1618476
# 2   /mnt/shared_data/finflow/gfw_raw/2024/CACFISH....          1716
# 3   /mnt/shared_data/finflow/gfw_raw/2024/CCSBT.pa...       5010026
# 4   /mnt/shared_data/finflow/gfw_raw/2024/ICCAT.pa...      14547988
# 5   /mnt/shared_data/finflow/gfw_raw/2024/IATTC.pa...       2822427
# 6   /mnt/shared_data/finflow/gfw_raw/2024/IOTC.par...       7995703
# 7   /mnt/shared_data/finflow/gfw_raw/2024/SPC.parquet       1084777
# 8   /mnt/shared_data/finflow/gfw_raw/2024/SPRFMO.p...        624472
# 9   /mnt/shared_data/finflow/gfw_raw/2024/SIOFA.pa...       1975627
# 10  /mnt/shared_data/finflow/gfw_raw/2024/SEAFDEC....       4124250
# 11  /mnt/shared_data/finflow/gfw_raw/2024/ICES.par...       2353755
# 12  /mnt/shared_data/finflow/gfw_raw/2024/NPAFC.pa...       1796514
# ...

# %%
import duckdb

global_path = "/mnt/shared_data/finflow/gfw_raw/2025/*.parquet"

stats = duckdb.query(f"""
    SELECT 
        -- Clean up the filename for easier reading
        replace(replace(filename, '/mnt/shared_data/finflow/gfw_raw/2025/', ''), '.parquet', '') as region,
        count(*) as unique_cells,           -- How many 11km squares have activity
        sum(hours) as total_hours,          -- THE KEY METRIC: Should increase after fix
        round(avg(hours), 2) as mean_hours,
        round(stddev(hours), 2) as std_dev, -- Variance in vessel intensity
        median(hours) as median_hours,      -- The 'typical' intensity in a cell
        max(hours) as max_hours
    FROM read_parquet('{global_path}', filename=True)
    GROUP BY filename
    ORDER BY total_hours DESC
""").df()

print(stats.to_string())
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#      region  unique_cells  total_hours  mean_hours  std_dev  median_hours  max_hours
# 0       IWC      39068151  204785322.0        5.24   131.20           1.0    66645.0
# 1      ACAP      39068151  204785322.0        5.24   131.20           1.0    66645.0
# 2     WCPFC      10968936  119330198.0       10.88   252.14           1.0    76567.0
# 3     ICCAT      15876169   62251076.0        3.92    96.57           1.0    68419.0
# 4     APFIC       4221933   49326609.0       11.68   225.38           2.0    52354.0
# 5     PICES       4941533   47477837.0        9.61   216.86           1.0    51877.0
# 6      IOTC       8747177   32091125.0        3.67    76.05           1.0    44564.0
# 7    NAMMCO       8832957   31381802.0        3.55    71.34           1.0    49663.0
# 8      GFCM       1692850   18546992.0       10.96   229.47           2.0    66645.0
# ...

# %%
import duckdb

global_path = "/mnt/shared_data/finflow/gfw_raw/2025/*.parquet"

stats = duckdb.query(f"""
    SELECT 
        -- Clean up the filename for easier reading
        replace(replace(filename, '/mnt/shared_data/finflow/gfw_raw/2025/', ''), '.parquet', '') as region,
        count(*) as unique_cells,           -- How many 11km squares have activity
        sum(hours) as total_hours,          -- THE KEY METRIC: Should increase after fix
        round(avg(hours), 2) as mean_hours,
        round(stddev(hours), 2) as std_dev, -- Variance in vessel intensity
        median(hours) as median_hours,      -- The 'typical' intensity in a cell
        max(hours) as max_hours
    FROM read_parquet('{global_path}', filename=True)
    GROUP BY filename
    ORDER BY total_hours DESC
""").df()

print(stats.to_string())
# Out:
#      region  unique_cells  total_hours  mean_hours  std_dev  median_hours  max_hours
# 0     APFIC       5029329   74914184.0       14.90   308.38           2.0    76567.0
# 1      ACAP      18418983   66186285.0        3.59    63.13           1.0    28231.0
# 2       IWC      15502771   52192659.0        3.37    53.68           1.0    15806.0
# 3   SEAFDEC       4556076   38437213.0        8.44   198.43           2.0    76478.0
# 4    NAMMCO       7783195   26051693.0        3.35    63.45           1.0    39616.0
# 5      IOTC       3419841    7750567.0        2.27    30.66           1.0    11235.0
# 6     NASCO       1827508    7065463.0        3.87    48.26           1.0    10400.0
# 7     IATTC       3009620    6703342.0        2.23    61.53           1.0    29047.0
# 8      NACA         18445    5841635.0      316.71  1303.81           9.0    33836.0
# 9     NEAFC       1073165    3851721.0        3.59    38.73           1.0     8351.0
# ...

# %%
import duckdb

# Replace with the path to one of your files
file_path = "/mnt/shared_data/finflow/gfw_raw/2025/SEAFDEC.parquet"

# 1. List all columns to see if 'date', 'timestamp', or 'time' exists
columns = duckdb.query(f"DESCRIBE SELECT * FROM '{file_path}'").df()
print("Available Columns:")
print(columns[['column_name', 'column_type']])

# 2. Check for unique dates (if a date column exists)
# Replace 'date' with the actual column name found above
try:
    unique_dates = duckdb.query(f"SELECT DISTINCT date FROM '{file_path}'").df()
    print(f"\nUnique dates found: {len(unique_dates)}")
    print(unique_dates)
except:
    print("\nNo date column found. This file likely contains aggregated data for the entire year.")
# Out:
# Available Columns:
#   column_name column_type
# 0         lat      DOUBLE
# 1         lon      DOUBLE
# 2       hours      DOUBLE
#
# No date column found. This file likely contains aggregated data for the entire year.
